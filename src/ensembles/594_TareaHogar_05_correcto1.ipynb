# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 09 05:05:38 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660336 35.3 1454485    77.7 1454485  77.7
# Vcells 1226517  9.4 8388608    64.0 1975136  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5950
PARAM$semilla_primigenia <- 105727

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 2L, upper= 1900L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8200L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 60 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83708
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sun Nov 09 05:24:14 PM 2025 AUC 0.924791429588408
#
# Sun Nov 09 05:28:05 PM 2025 AUC 0.92420531355543
#
# Sun Nov 09 05:32:48 PM 2025 AUC 0.925739027386308
#
# Sun Nov 09 05:36:23 PM 2025 AUC 0.925931754368316
#
# Sun Nov 09 05:39:25 PM 2025 AUC 0.92486720087122
#
# Sun Nov 09 05:40:31 PM 2025 AUC 0.923957250986149
#
# Sun Nov 09 05:42:51 PM 2025 AUC 0.923127354386212
#
# Sun Nov 09 05:43:00 PM 2025 AUC 0.918317664140132
#
# Sun Nov 09 05:46:35 PM 2025 AUC 0.922936095997404
#
# Sun Nov 09 05:48:58 PM 2025 AUC 0.924451660299541
#
# Sun Nov 09 05:54:08 PM 2025 AUC 0.925951943532745
#
# Sun Nov 09 05:54:54 PM 2025 AUC 0.921386006580339
#
# Sun Nov 09 05:59:04 PM 2025 AUC 0.922433251164138
#
# Sun Nov 09 05:59:26 PM 2025 AUC 0.923013361746362
#
# Sun Nov 09 06:00:48 PM 2025 AUC 0.921082745458427
#
# Sun Nov 09 06:07:21 PM 2025 AUC 0.926219782093524
#
# Sun Nov 09 06:11:00 PM 2025 AUC 0.928614234839793
#
# Sun Nov 09 06:14:00 PM 2025 AUC 0.927648125848224
#
# Sun Nov 09 06:17:21 PM 2025 AUC 0.923952276725528
#
# Sun Nov 09 06:18:20 PM 2025 AUC 0.924801473997122
#
# [mbo] 0: num_iterations=1723; learning_rate=0.117; feature_fraction=0.77; num_leaves=942; min_data_in_leaf=6152 : y = 0.925 : 198.3 secs : initdesign
#
# [mbo] 0: num_iterations=1064; learning_rate=0.197; feature_fraction=0.515; num_leaves=1267; min_data_in_leaf=4581 : y = 0.924 : 230.6 secs : initdesign
#
# [mbo] 0: num_iterations=1538; learning_rate=0.158; feature_fraction=0.591; num_leaves=1588; min_data_in_leaf=3946 : y = 0.926 : 282.6 secs : initdesign
#
# [mbo] 0: num_iterations=904; learning_rate=0.103; feature_fraction=0.477; num_leaves=408; min_data_in_leaf=1925 : y = 0.926 : 215.3 secs : initdesign
#
# [mbo] 0: num_iterations=1421; learning_rate=0.0662; feature_fraction=0.126; num_leaves=1381; min_data_in_leaf=5613 : y = 0.925 : 181.8 secs : initdesign
#
# [mbo] 0: num_iterations=616; learning_rate=0.178; feature_fraction=0.728; num_leaves=1463; min_data_in_leaf=7259 : y = 0.924 : 66.6 secs : initdesign
#
# [mbo] 0: num_iterations=821; learning_rate=0.243; feature_fraction=0.317; num_leaves=654; min_data_in_leaf=6791 : y = 0.923 : 140.0 secs : initdesign
#
# [mbo] 0: num_iterations=36; learning_rate=0.083; feature_fraction=0.598; num_leaves=960; min_data_in_leaf=3652 : y = 0.918 : 8.7 secs : initdesign
#
# [mbo] 0: num_iterations=1558; learning_rate=0.226; feature_fraction=0.155; num_leaves=308; min_data_in_leaf=4424 : y = 0.923 : 214.8 secs : initdesign
#
# [mbo] 0: num_iterations=982; learning_rate=0.205; feature_fraction=0.906; num_leaves=1131; min_data_in_leaf=2499 : y = 0.924 : 143.3 secs : initdesign
#
# [mbo] 0: num_iterations=1788; learning_rate=0.138; feature_fraction=0.664; num_leaves=830; min_data_in_leaf=1559 : y = 0.926 : 309.9 secs : initdesign
#
# [mbo] 0: num_iterations=244; learning_rate=0.0291; feature_fraction=0.34; num_leaves=189; min_data_in_leaf=5842 : y = 0.921 : 46.5 secs : initdesign
#
# [mbo] 0: num_iterations=1285; learning_rate=0.262; feature_fraction=0.426; num_leaves=1662; min_data_in_leaf=7857 : y = 0.922 : 249.5 secs : initdesign
#
# [mbo] 0: num_iterations=142; learning_rate=0.284; feature_fraction=0.777; num_leaves=227; min_data_in_leaf=2367 : y = 0.923 : 21.8 secs : initdesign
#
# [mbo] 0: num_iterations=424; learning_rate=0.297; feature_fraction=0.92; num_leaves=1881; min_data_in_leaf=1131 : y = 0.921 : 81.9 secs : initdesign
#
# [mbo] 0: num_iterations=2047; learning_rate=0.0824; feature_fraction=0.381; num_leaves=1727; min_data_in_leaf=5085 : y = 0.926 : 393.5 secs : initdesign
#
# [mbo] 0: num_iterations=1160; learning_rate=0.0535; feature_fraction=0.222; num_leaves=71; min_data_in_leaf=330 : y = 0.929 : 218.7 secs : initdesign
#
# [mbo] 0: num_iterations=711; learning_rate=0.0101; feature_fraction=0.997; num_leaves=671; min_data_in_leaf=495 : y = 0.928 : 180.2 secs : initdesign
#
# [mbo] 0: num_iterations=1904; learning_rate=0.15; feature_fraction=0.827; num_leaves=505; min_data_in_leaf=7692 : y = 0.924 : 200.9 secs : initdesign
#
# [mbo] 0: num_iterations=340; learning_rate=0.239; feature_fraction=0.263; num_leaves=1194; min_data_in_leaf=3208 : y = 0.925 : 58.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Sun Nov 09 06:21:18 PM 2025 AUC 0.92309505548133
#
# [mbo] 1: num_iterations=1447; learning_rate=0.0108; feature_fraction=0.595; num_leaves=3; min_data_in_leaf=1 : y = 0.923 : 177.4 secs : infill_ei
#
# Sun Nov 09 06:26:15 PM 2025 AUC 0.927157597727228
#
# [mbo] 2: num_iterations=1034; learning_rate=0.0479; feature_fraction=0.302; num_leaves=308; min_data_in_leaf=38 : y = 0.927 : 296.4 secs : infill_ei
#
# Sun Nov 09 06:29:27 PM 2025 AUC 0.925800483589396
#
# [mbo] 3: num_iterations=1149; learning_rate=0.078; feature_fraction=0.174; num_leaves=45; min_data_in_leaf=1189 : y = 0.926 : 192.0 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Sun Nov 09 06:34:43 PM 2025 AUC 0.924165945400716
#
# [mbo] 4: num_iterations=1637; learning_rate=0.0494; feature_fraction=0.426; num_leaves=198; min_data_in_leaf=6853 : y = 0.924 : 315.1 secs : infill_ei
#
# Sun Nov 09 06:36:28 PM 2025 AUC 0.926504010304987
#
# [mbo] 5: num_iterations=467; learning_rate=0.0553; feature_fraction=0.2; num_leaves=229; min_data_in_leaf=347 : y = 0.927 : 105.0 secs : infill_ei
#
# Sun Nov 09 06:40:28 PM 2025 AUC 0.929004715915374
#
# [mbo] 6: num_iterations=1625; learning_rate=0.053; feature_fraction=0.247; num_leaves=9; min_data_in_leaf=235 : y = 0.929 : 239.4 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Sun Nov 09 06:46:30 PM 2025 AUC 0.927266790609662
#
# [mbo] 7: num_iterations=1498; learning_rate=0.0549; feature_fraction=0.236; num_leaves=789; min_data_in_leaf=281 : y = 0.927 : 361.8 secs : infill_ei
#
# Sun Nov 09 06:50:31 PM 2025 AUC 0.927746627848838
#
# [mbo] 8: num_iterations=1814; learning_rate=0.0481; feature_fraction=0.198; num_leaves=5; min_data_in_leaf=1 : y = 0.928 : 240.6 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesiana.RDATA.
#
# Sun Nov 09 06:53:39 PM 2025 AUC 0.926890842764501
#
# [mbo] 9: num_iterations=1322; learning_rate=0.0504; feature_fraction=0.241; num_leaves=4; min_data_in_leaf=1122 : y = 0.927 : 187.4 secs : infill_ei
#
# Sun Nov 09 07:01:32 PM 2025 AUC 0.929907612541087
#
# [mbo] 10: num_iterations=1975; learning_rate=0.0518; feature_fraction=0.532; num_leaves=47; min_data_in_leaf=433 : y = 0.93 : 471.8 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Sun Nov 09 07:07:52 PM 2025 AUC 0.926810554614175
#
# [mbo] 11: num_iterations=2045; learning_rate=0.0578; feature_fraction=0.742; num_leaves=105; min_data_in_leaf=17 : y = 0.927 : 379.5 secs : infill_ei
#
# Sun Nov 09 07:14:13 PM 2025 AUC 0.929050517278169
#
# [mbo] 12: num_iterations=1622; learning_rate=0.0537; feature_fraction=0.481; num_leaves=49; min_data_in_leaf=319 : y = 0.929 : 380.6 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Sun Nov 09 07:20:12 PM 2025 AUC 0.927692898712984
#
# [mbo] 13: num_iterations=1904; learning_rate=0.0495; feature_fraction=0.178; num_leaves=105; min_data_in_leaf=519 : y = 0.928 : 358.2 secs : infill_ei
#
# Sun Nov 09 07:26:06 PM 2025 AUC 0.927929782558643
#
# [mbo] 14: num_iterations=1978; learning_rate=0.0507; feature_fraction=0.611; num_leaves=67; min_data_in_leaf=28 : y = 0.928 : 353.6 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Sun Nov 09 07:31:16 PM 2025 AUC 0.929007463651172
#
# [mbo] 15: num_iterations=1952; learning_rate=0.0505; feature_fraction=0.631; num_leaves=36; min_data_in_leaf=628 : y = 0.929 : 309.8 secs : infill_ei
#
# Sun Nov 09 07:38:32 PM 2025 AUC 0.930559818298845
#
# [mbo] 16: num_iterations=2044; learning_rate=0.0582; feature_fraction=0.474; num_leaves=25; min_data_in_leaf=559 : y = 0.931 : 435.3 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Sun Nov 09 07:45:59 PM 2025 AUC 0.929661113735251
#
# [mbo] 17: num_iterations=2041; learning_rate=0.069; feature_fraction=0.517; num_leaves=26; min_data_in_leaf=570 : y = 0.93 : 446.3 secs : infill_ei
#
# Sun Nov 09 07:52:33 PM 2025 AUC 0.927541082309193
#
# [mbo] 18: num_iterations=2043; learning_rate=0.0577; feature_fraction=0.513; num_leaves=7; min_data_in_leaf=1479 : y = 0.928 : 394.0 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Sun Nov 09 07:58:47 PM 2025 AUC 0.928940864443063
#
# [mbo] 19: num_iterations=2047; learning_rate=0.058; feature_fraction=0.39; num_leaves=16; min_data_in_leaf=452 : y = 0.929 : 373.4 secs : infill_ei
#
# Sun Nov 09 08:07:24 PM 2025 AUC 0.928254938917811
#
# [mbo] 20: num_iterations=2047; learning_rate=0.114; feature_fraction=0.462; num_leaves=65; min_data_in_leaf=528 : y = 0.928 : 515.6 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Sun Nov 09 08:17:04 PM 2025 AUC 0.929344597447846
#
# [mbo] 21: num_iterations=1998; learning_rate=0.0579; feature_fraction=0.502; num_leaves=1153; min_data_in_leaf=637 : y = 0.929 : 579.4 secs : infill_ei
#
# Sun Nov 09 08:24:34 PM 2025 AUC 0.929021215011539
#
# [mbo] 22: num_iterations=2046; learning_rate=0.041; feature_fraction=0.999; num_leaves=1404; min_data_in_leaf=753 : y = 0.929 : 450.1 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Sun Nov 09 08:33:51 PM 2025 AUC 0.925370067382353
#
# [mbo] 23: num_iterations=2008; learning_rate=0.0589; feature_fraction=0.471; num_leaves=326; min_data_in_leaf=6 : y = 0.925 : 555.9 secs : infill_ei
#
# Sun Nov 09 08:34:12 PM 2025 AUC 0.925753073073281
#
# [mbo] 24: num_iterations=164; learning_rate=0.0516; feature_fraction=0.1; num_leaves=25; min_data_in_leaf=165 : y = 0.926 : 20.9 secs : infill_ei
#
# Sun Nov 09 08:40:50 PM 2025 AUC 0.927155783409226
#
# [mbo] 25: num_iterations=1422; learning_rate=0.0448; feature_fraction=0.996; num_leaves=221; min_data_in_leaf=368 : y = 0.927 : 397.2 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Sun Nov 09 08:47:51 PM 2025 AUC 0.929341736245758
#
# [mbo] 26: num_iterations=1545; learning_rate=0.0531; feature_fraction=0.491; num_leaves=736; min_data_in_leaf=817 : y = 0.929 : 419.7 secs : infill_ei
#
# Sun Nov 09 08:54:20 PM 2025 AUC 0.930754210856384
#
# [mbo] 27: num_iterations=1971; learning_rate=0.0547; feature_fraction=0.479; num_leaves=12; min_data_in_leaf=687 : y = 0.931 : 388.5 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana.RDATA.
#
# Sun Nov 09 09:01:22 PM 2025 AUC 0.928383935471557
#
# [mbo] 28: num_iterations=1529; learning_rate=0.051; feature_fraction=0.499; num_leaves=1897; min_data_in_leaf=878 : y = 0.928 : 421.8 secs : infill_ei
#
# Sun Nov 09 09:06:51 PM 2025 AUC 0.928763601917169
#
# [mbo] 29: num_iterations=1802; learning_rate=0.0542; feature_fraction=0.47; num_leaves=5; min_data_in_leaf=593 : y = 0.929 : 328.2 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Sun Nov 09 09:16:07 PM 2025 AUC 0.929673559740334
#
# [mbo] 30: num_iterations=2042; learning_rate=0.0467; feature_fraction=0.485; num_leaves=163; min_data_in_leaf=765 : y = 0.93 : 555.0 secs : infill_ei
#
# Sun Nov 09 09:24:17 PM 2025 AUC 0.929531850805267
#
# [mbo] 31: num_iterations=1842; learning_rate=0.074; feature_fraction=0.484; num_leaves=1032; min_data_in_leaf=899 : y = 0.93 : 489.8 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Sun Nov 09 09:32:32 PM 2025 AUC 0.919680203110676
#
# [mbo] 32: num_iterations=2047; learning_rate=0.225; feature_fraction=0.526; num_leaves=599; min_data_in_leaf=310 : y = 0.92 : 494.9 secs : infill_ei
#
# Sun Nov 09 09:41:30 PM 2025 AUC 0.927429792848886
#
# [mbo] 33: num_iterations=1919; learning_rate=0.0574; feature_fraction=0.497; num_leaves=1089; min_data_in_leaf=713 : y = 0.927 : 537.4 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Sun Nov 09 09:45:02 PM 2025 AUC 0.929127974853961
#
# [mbo] 34: num_iterations=839; learning_rate=0.0619; feature_fraction=0.392; num_leaves=289; min_data_in_leaf=657 : y = 0.929 : 211.0 secs : infill_ei
#
# Sun Nov 09 09:50:26 PM 2025 AUC 0.926763659998447
#
# [mbo] 35: num_iterations=1961; learning_rate=0.0541; feature_fraction=0.237; num_leaves=31; min_data_in_leaf=2984 : y = 0.927 : 323.1 secs : infill_ei
#
# Sun Nov 09 09:56:26 PM 2025 AUC 0.929049578427636
#
# [mbo] 36: num_iterations=1394; learning_rate=0.0608; feature_fraction=0.447; num_leaves=73; min_data_in_leaf=717 : y = 0.929 : 359.4 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Sun Nov 09 10:00:24 PM 2025 AUC 0.928757010201916
#
# [mbo] 37: num_iterations=1912; learning_rate=0.0497; feature_fraction=0.833; num_leaves=24; min_data_in_leaf=811 : y = 0.929 : 237.4 secs : infill_ei
#
# Sun Nov 09 10:01:43 PM 2025 AUC 0.923439242169097
#
# [mbo] 38: num_iterations=413; learning_rate=0.263; feature_fraction=0.323; num_leaves=29; min_data_in_leaf=3172 : y = 0.923 : 78.7 secs : infill_ei
#
# Sun Nov 09 10:11:17 PM 2025 AUC 0.928173753740977
#
# [mbo] 39: num_iterations=2044; learning_rate=0.0586; feature_fraction=0.516; num_leaves=167; min_data_in_leaf=692 : y = 0.928 : 573.6 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Sun Nov 09 10:17:01 PM 2025 AUC 0.92599559241771
#
# [mbo] 40: num_iterations=1435; learning_rate=0.198; feature_fraction=0.541; num_leaves=165; min_data_in_leaf=1784 : y = 0.926 : 343.5 secs : infill_ei
#
# Sun Nov 09 10:22:02 PM 2025 AUC 0.929188493731524
#
# [mbo] 41: num_iterations=1353; learning_rate=0.0483; feature_fraction=0.314; num_leaves=376; min_data_in_leaf=766 : y = 0.929 : 300.1 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Sun Nov 09 10:22:27 PM 2025 AUC 0.924378863216121
#
# [mbo] 42: num_iterations=183; learning_rate=0.0486; feature_fraction=0.809; num_leaves=1507; min_data_in_leaf=4876 : y = 0.924 : 24.6 secs : infill_ei
#
# Sun Nov 09 10:25:26 PM 2025 AUC 0.928316887680181
#
# [mbo] 43: num_iterations=1663; learning_rate=0.0624; feature_fraction=0.798; num_leaves=18; min_data_in_leaf=567 : y = 0.928 : 178.4 secs : infill_ei
#
# Sun Nov 09 10:28:12 PM 2025 AUC 0.923253382269948
#
# [mbo] 44: num_iterations=1598; learning_rate=0.276; feature_fraction=0.988; num_leaves=10; min_data_in_leaf=2435 : y = 0.923 : 165.2 secs : infill_ei
#
# Sun Nov 09 10:30:39 PM 2025 AUC 0.929294106226907
#
# [mbo] 45: num_iterations=653; learning_rate=0.0554; feature_fraction=0.327; num_leaves=1143; min_data_in_leaf=901 : y = 0.929 : 146.9 secs : infill_ei
#
# Sun Nov 09 10:33:55 PM 2025 AUC 0.924313089421464
#
# [mbo] 46: num_iterations=1569; learning_rate=0.254; feature_fraction=0.873; num_leaves=867; min_data_in_leaf=4321 : y = 0.924 : 194.8 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Sun Nov 09 10:34:38 PM 2025 AUC 0.924085335819958
#
# [mbo] 47: num_iterations=355; learning_rate=0.258; feature_fraction=0.917; num_leaves=811; min_data_in_leaf=4704 : y = 0.924 : 42.8 secs : infill_ei
#
# Sun Nov 09 10:40:20 PM 2025 AUC 0.923353670789222
#
# [mbo] 48: num_iterations=1748; learning_rate=0.129; feature_fraction=0.827; num_leaves=720; min_data_in_leaf=273 : y = 0.923 : 341.2 secs : infill_ei
#
# Sun Nov 09 10:46:43 PM 2025 AUC 0.925756623864197
#
# [mbo] 49: num_iterations=1828; learning_rate=0.0522; feature_fraction=0.498; num_leaves=20; min_data_in_leaf=5121 : y = 0.926 : 383.0 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Sun Nov 09 10:48:50 PM 2025 AUC 0.924281999809095
#
# [mbo] 50: num_iterations=1179; learning_rate=0.192; feature_fraction=0.668; num_leaves=1319; min_data_in_leaf=7426 : y = 0.924 : 126.5 secs : infill_ei
#
# Sun Nov 09 10:55:10 PM 2025 AUC 0.929230826720246
#
# [mbo] 51: num_iterations=1770; learning_rate=0.0506; feature_fraction=0.632; num_leaves=1253; min_data_in_leaf=864 : y = 0.929 : 379.3 secs : infill_ei
#
# Sun Nov 09 11:02:20 PM 2025 AUC 0.927507383454477
#
# [mbo] 52: num_iterations=1874; learning_rate=0.06; feature_fraction=0.665; num_leaves=1313; min_data_in_leaf=599 : y = 0.928 : 428.9 secs : infill_ei
#
# Saved the current state after iteration 53 in the file bayesiana.RDATA.
#
# Sun Nov 09 11:06:43 PM 2025 AUC 0.918469274583151
#
# [mbo] 53: num_iterations=1423; learning_rate=0.151; feature_fraction=0.149; num_leaves=1211; min_data_in_leaf=153 : y = 0.918 : 262.8 secs : infill_ei
#
# Sun Nov 09 11:14:05 PM 2025 AUC 0.929362947409971
#
# [mbo] 54: num_iterations=1982; learning_rate=0.0505; feature_fraction=0.469; num_leaves=40; min_data_in_leaf=307 : y = 0.929 : 441.5 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Sun Nov 09 11:18:53 PM 2025 AUC 0.929653912499546
#
# [mbo] 55: num_iterations=1080; learning_rate=0.052; feature_fraction=0.467; num_leaves=627; min_data_in_leaf=793 : y = 0.93 : 286.7 secs : infill_ei
#
# Sun Nov 09 11:20:58 PM 2025 AUC 0.926776044469032
#
# [mbo] 56: num_iterations=719; learning_rate=0.0417; feature_fraction=0.287; num_leaves=1495; min_data_in_leaf=4357 : y = 0.927 : 125.1 secs : infill_ei
#
# Sun Nov 09 11:30:49 PM 2025 AUC 0.929349005440013
#
# [mbo] 57: num_iterations=2031; learning_rate=0.0525; feature_fraction=0.466; num_leaves=1185; min_data_in_leaf=507 : y = 0.929 : 589.8 secs : infill_ei
#
# Saved the current state after iteration 58 in the file bayesiana.RDATA.

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
